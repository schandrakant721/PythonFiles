# %%
class Student:
    def getGrades(self):             #self is nothing but just a place holder(It take arguments but we dont pass then also it will not throw error.We use this because python doesnt know what is to be passed
        print("Hey")

s1 = Student()
s2 = Student()
#s1.getGrades()
        
Student.getGrades(s1)  
s2.getGrades()
# Out:
# Hey
# Hey

# %%
class Animal:
    def walk(self):
        print('Animal Walkes')


        
        
cow = Animal()
elephant = Animal()
#cow.walk()        #not good waay to write code
Animal.walk(cow)   #good way 
Animal.walk(elephant)

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def sayHi(self):
        print(f'Hi, {slef.name} who is {self.age} year old')
          

            
            
p1 = Person("Pa",18)
#p1.name    
p1.sayHi(p1)

# %%
#####################

# %%
#python can return multiple values
def foo():
    return 1,2
a,b = foo()
print(b)
# Out:
# 2

# %%
#tiktok game

def drawBoard():
    print('''
    \t|\t|\t
    ----------------
    \t|\t|\t
    ---------------
    \t|\t|\t
    ---------------
    ''')
drawBoard()

# %%
#tiktok game
board = [' ' for i in range(9)]
def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    ----------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    ---------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    ---------------
    ''')

def getInput():
    x = int(input("Enter a position:"))
    board[x] = "X"
drawBoard() 
getInput()
drawBoard()

# %%
#tiktak game // need to add some thing
board = [' ' for i in range(9)]
def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    ----------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    ---------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    ---------------
    ''')

def getInput():
    x = int(input("Enter a position:"))
    board[x] = "X"
drawBoard() 
getInput()
drawBoard()
# Out:
#     	 |	 |
#     ----------------
#     	 |	 |
#     ---------------
#     	 |	 |
#     ---------------
#
# Enter a position:1
#
#     	 |	X|
#     ----------------
#     	 |	 |
#     ---------------
#     	 |	 |
#     ---------------

# %%
# Another problem if we put same position then ti should say it is invalid or occupied

# %%
#tiktok game
board = [' ' for i in range(9)]
def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    --------------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    --------------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    --------------------
    ''')

def getInput():
    x = int(input("Enter a position:"))
    board[x] = "X"
drawBoard() 
getInput()
drawBoard()
getInput()
drawBoard()
# Out:
#     	 |	 |
#     --------------------
#     	 |	 |
#     --------------------
#     	 |	 |
#     --------------------
#
# Enter a position:5
#
#     	 |	 |
#     --------------------
#     	 |	 |	X
#     --------------------
#     	 |	 |
#     --------------------
#
# Enter a position:5
#
#     	 |	 |
#     --------------------
#     	 |	 |	X
#     --------------------
#     	 |	 |
#     --------------------

# %%
# now i am adding something to fix the bug

board = [' ' for i in range(9)]
def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    --------------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    --------------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    --------------------
    ''')

def getInput():
    pos = int(input("Enter a position:"))
    if pos<0 or pos>8:
        print("Invalid position") 
    elif board[pos] != ' ' :                # it will check that the position is occupied or not by comparing with blank space  
        print("Position occupied")
    else:
        board[pos] = "X"
drawBoard() 
getInput()
drawBoard()
getInput()
drawBoard()
# Out:
#     	 |	 |
#     --------------------
#     	 |	 |
#     --------------------
#     	 |	 |
#     --------------------
#
# Enter a position:5
#
#     	 |	 |
#     --------------------
#     	 |	 |	X
#     --------------------
#     	 |	 |
#     --------------------
#
# Enter a position:5
# Position occupied
#
#     	 |	 |
#     --------------------
#     	 |	 |	X
#     --------------------
#     	 |	 |
#     --------------------

# %%
#fixed some bugs

# %%
board = [' ' for i in range(9)]

sign = "X"
player = 1
turn = True
gameOver = False    #sign x and player 1 is default condition and gmaeOver is also false untill some one win
count = 0


def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    --------------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    --------------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    --------------------
    ''')

def getInput():
    if turn:
        player =1
        sign ="X"
    else:
        player = 2
        sign = "O"
    
    
    
    pos = int(input("Enter a position:"))
    if pos<0 or pos>8:
        print("Invalid position") 
    elif board[pos] != ' ' :                # it will check that the position is occupied or not by comparing with blank space  
        print("Position occupied")
    else:
        board[pos] = "X"
drawBoard() 
getInput()
drawBoard()
getInput()
drawBoard()

# %%
# still our turn is not getting change
#solved problem

board = [' ' for i in range(9)]

sign = "X"
player = 1
turn = True
gameOver = False    #sign x and player 1 is default condition and gmaeOver is also false untill some one win
count = 0


def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    --------------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    --------------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    --------------------
    ''')

def getInput():
    if turn:
        player =1
        sign ="X"
    else:
        player = 2
        sign = "O"
    
    
    
    pos = int(input("Enter a position:"))
    if pos<0 or pos>8:
        print("Invalid position") 
    elif board[pos] != ' ' :                # it will check that the position is occupied or not by comparing with blank space  
        print("Position occupied")
    else:
        #board[pos] = sign
        return pos

def playTurn():
    drawBoard()
    while(count != 9):
        pos = getInput()
        if pos is not None:
            count+=1
            board[pos] = sign
            turn = not(turn)      # like not gate
            drawBoard()

playTurn()

# %%
#encounter count problem.  Here i solved that

board = [' ' for i in range(9)]

sign = "X"
player = 1
turn = True
gameOver = False    #sign x and player 1 is default condition and gmaeOver is also false untill some one win
count = 0


def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    --------------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    --------------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    --------------------
    ''')

def getInput():
    global turn
    global player
    global sign
    
    if turn:
        player =1
        sign ="X"
    else:
        player = 2
        sign = "O"
    
    
    
    pos = int(input("Enter a position:"))
    if pos<0 or pos>8:
        print("Invalid position") 
    elif board[pos] != ' ' :                # it will check that the position is occupied or not by comparing with blank space  
        print("Position occupied")
    else:
        #board[pos] = sign
        return pos

def playTurn():
    global count    #becoz count is not defined in this function but its some where and we use that 
    global turn
    global players
    drawBoard()
    while(count != 9):
        pos = getInput()
        if pos is not None:
            count+=1
            board[pos] = sign
            turn = not(turn)      # like not gate
            drawBoard()

playTurn()

# %%
#it is still wierd, we only getting X
board = [' ' for i in range(9)]

sign = "X"
player = 1
turn = True
gameOver = False    #sign x and player 1 is default condition and gmaeOver is also false untill some one win
count = 0


def drawBoard():
    print(f'''
    \t{board[0]}|\t{board[1]}|\t{board[2]}
    --------------------
    \t{board[3]}|\t{board[4]}|\t{board[5]}
    --------------------
    \t{board[6]}|\t{board[7]}|\t{board[8]}
    --------------------
    ''')

def getInput():
    global turn
    global player
    global sign
    
    if turn:
        player =1
        sign ="X"
    else:
        player = 2
        sign = "O"
    
    
    
    pos = int(input("Enter a position:"))
    if pos<0 or pos>8:
        print("Invalid position") 
    elif board[pos] != ' ' :                # it will check that the position is occupied or not by comparing with blank space  
        print("Position occupied")
    else:
        #board[pos] = sign
        return pos

def playTurn():
    global count    #becoz count is not defined in this function but its some where and we use that 
    global turn
    global players
    drawBoard()
    while(count != 9):
        pos = getInput()
        if pos is not None:
            count+=1
            board[pos] = sign
            turn = not(turn)      # like not gate
            drawBoard()

playTurn()
